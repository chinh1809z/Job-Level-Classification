# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("../data/job_classification.ods", engine = "odf", dtype = str)

# %%
data.head()
# Out:
#                                                title        location  \
# 0              Technical Professional Lead - Process     Houston, TX
# 1                    Cnslt - Systems Eng- Midrange 1     Seattle, WA
# 2      SharePoint Developers and Solution Architects      Dallas, TX
# 3  Business Information Services - Strategic Acco...  North Carolina
# 4       Strategic Development Director (procurement)      Austin, TX
#
#                                          description  \
# 0  Responsible for the study, design, and specifi...
# 1  Participates in design, development and implem...
# 2  We are currently in need of Developers who can...
# 3  Experian is seeking an experienced Account Exe...
# 4  Â Want to join a world-class global procuremen...
#
#                                     function  \
# 0                   production_manufacturing
# 1  information_technology_telecommunications
# 2                                 consulting
# ...

# %%
data.shape
# Out:
# (8074, 6)

# %%
data.columns
# Out:
# Index(['title', 'location', 'description', 'function', 'industry',
#        'career_level'],
#       dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8074 entries, 0 to 8073
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         8074 non-null   str
#  1   location      8074 non-null   str
#  2   description   8073 non-null   str
#  3   function      8074 non-null   str
#  4   industry      8074 non-null   str
#  5   career_level  8074 non-null   str
# dtypes: str(6)
# memory usage: 378.6 KB

# %%
data.isnull().sum
# Out:
# <bound method DataFrame.sum of       title  location  description  function  industry  career_level
# 0     False     False        False     False     False         False
# 1     False     False        False     False     False         False
# 2     False     False        False     False     False         False
# 3     False     False        False     False     False         False
# 4     False     False        False     False     False         False
# ...     ...       ...          ...       ...       ...           ...
# 8069  False     False        False     False     False         False
# 8070  False     False        False     False     False         False
# 8071  False     False        False     False     False         False
# 8072  False     False        False     False     False         False
# 8073  False     False        False     False     False         False
#
# [8074 rows x 6 columns]>

# %%
data.isnull().mean() * 100
# Out:
# title           0.000000
# location        0.000000
# description     0.012385
# function        0.000000
# industry        0.000000
# career_level    0.000000
# dtype: float64

# %%
data[data['description'].isnull()]
# Out:
#                              title     location description function  \
# 5581  Area Sales Manager (Houston)  Houston, TX         NaN    sales
#
#                     industry                          career_level
# 5581  Aircraft Manufacturing  senior_specialist_or_project_manager

# %%
data.duplicated().sum()
# Out:
# np.int64(21)

# %%
data[data.duplicated(keep=False)].sort_values("title")
# Out:
#                                                   title           location  \
# 96                                      Account Manager           Troy, MI
# 7835                                    Account Manager       Portland, OR
# 7331                                    Account Manager       Portland, OR
# 6435                                    Account Manager           Troy, MI
# 7904   Account Manager, Hydronics Industry (Eastern US)         Boston, MA
# 7873   Account Manager, Hydronics Industry (Eastern US)         Boston, MA
# 700    Account Representative, MUNICIPEX (Northeast US)         Boston, MA
# 7013   Account Representative, MUNICIPEX (Northeast US)         Boston, MA
# 7979              Business Development Manager/Director        Houston, TX
# 7524              Business Development Manager/Director        Houston, TX
# 1344               Data Network and Security Consultant                USA
# ...

# %%
data["career_level"].value_counts()
# Out:
# career_level
# senior_specialist_or_project_manager      4338
# manager_team_leader                       2672
# bereichsleiter                             960
# director_business_unit_leader               70
# specialist                                  30
# managing_director_small_medium_company       4
# Name: count, dtype: int64

# %%
data["career_level"].value_counts(normalize = True) * 100
# Out:
# career_level
# senior_specialist_or_project_manager      53.728016
# manager_team_leader                       33.093882
# bereichsleiter                            11.890017
# director_business_unit_leader              0.866980
# specialist                                 0.371563
# managing_director_small_medium_company     0.049542
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10, 5))

data["career_level"].value_counts().plot(kind="bar")

plt.title("Career Level Distribution")
plt.xlabel("Career Level")
plt.ylabel("Number of Jobs")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
print("Location: ", data["location"].nunique())
print("Function: ", data["function"].nunique())
print("Industry: ", data["industry"].nunique())
# Out:
# Location:  1081
# Function:  19
# Industry:  352

# %%
data[data["description"].isnull()]
# Out:
#                              title     location description function  \
# 5581  Area Sales Manager (Houston)  Houston, TX         NaN    sales
#
#                     industry                          career_level
# 5581  Aircraft Manufacturing  senior_specialist_or_project_manager
